# %% [markdown]
# Culture of a place is defined by the food of the placed. This program gives you the clustering of various restaurants in Delhi.

# %%
Import All the required libraries

# %%
import requests
import pandas as pd
import folium
import numpy as np
import geopy.geocoders
from geopy.geocoders import Nominatim
import certifi
import time
import ssl
import csv

# %% [markdown]
# Collecting all the data of discticts and neighbourhoods

# %%
url = "https://en.wikipedia.org/wiki/List_of_districts_of_Delhi"
html = requests.get(url).content
df_list = pd.read_html(html)
df = pd.DataFrame(columns = ['District','Neighbourhood' ,'Latitude', 'Longitude'])
df_district = df_list[0]['District']
df_head = df_list[0]['Headquarters']
df_sd1 = df_list[0]['Sub divisions (Tehsils)']
df_sd2 = df_list[0]['Sub divisions (Tehsils).1']
df_sd3 = df_list[0]['Sub divisions (Tehsils).2']
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
geopy.geocoders.options.default_ssl_context = ctx
geolocator = Nominatim()
for i in range(len(df_district)):
    #First Sub Division
    if(df_sd1[i].find('[') > 0):
        df_sd1[i] = df_sd1[i][0:df_sd1[i].find('[')]
    location = None
    while(location == None):
        address = df_sd1[i] + ", Delhi"
        try:
            location = geolocator.geocode(address)
        except:
            location = None
    lat = location.latitude
    long = location.longitude
    temp = [df_district[i], df_sd1[i], lat, long]
    df.loc[len(df)] = temp
    print(temp)
    #Second Sub Division
    if(df_sd2[i].find('[') > 0):
        df_sd2[i] = df_sd2[i][0:df_sd2[i].find('[')]
    location = None
    while(location == None):
        address = df_sd3[i] + ", Delhi"
        try:
            location = geolocator.geocode(address)
        except:
            location = None
    lat = location.latitude
    long = location.longitude
    temp = [df_district[i], df_sd2[i], lat, long]
    df.loc[len(df)] = temp
    print(temp)
     #Third Sub Division'
    if(df_sd3[i].find('[') > 0):
        df_sd3[i] = df_sd3[i][0:df_sd3[i].find('[')]
    location = None
    while(location == None):
        address = df_sd3[i] + ", Delhi"
        try:
            location = geolocator.geocode(address)
        except:
            location = None
    lat = location.latitude
    long = location.longitude
    temp = [df_district[i], df_sd3[i], lat, long]
    df.loc[len(df)] = temp
    print(temp)
    if(df_head[i].find('[') > 0):
        df_head[i] = df_head[i][0:df_head[i].find('[')]
    if(df_head[i] != df_sd1[i] and df_head[i] != df_sd2[i] and df_head[i] != df_sd3[i] ):
        location = None
        while(location == None):
            address = df_head[i] + ", Delhi"
            try:
                location = geolocator.geocode(address)
            except:
                location = None
        lat = location.latitude
        long = location.longitude
        temp = [df_district[i], df_head[i], lat, long]
        df.loc[len(df)] = temp
        print(temp)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# ['New Delhi', 'Chanakyapuri', 28.5946775, 77.1885212]
# ['New Delhi', 'Delhi Cantonment', 28.56069055, 77.1607907316857]
# ['New Delhi', 'Vasant Vihar', 28.56069055, 77.1607907316857]
# ['New Delhi', 'Connaught Place', 28.6313827, 77.2197924]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['North Delhi', 'Model Town', 28.7027391, 77.1940059]
# ['North Delhi', 'Narela', 28.7959955, 77.1360706]
# ['North Delhi', 'Alipur', 28.7959955, 77.1360706]
# ['North West Delhi', 'Rohini', 28.7162092, 77.1170743]
# ['North West Delhi', 'Kanjhawala', 28.4772236, 77.0832762]
# ['North West Delhi', 'Saraswati Vihar', 28.4772236, 77.0832762]
# ['West Delhi', 'Patel Nagar', 28.6598088, 77.156957]
# ['West Delhi', 'Punjabi Bagh', 28.6421518, 77.1160603776926]
# ['West Delhi', 'Rajouri Garden', 28.6421518, 77.1160603776926]
# ['South West Delhi', 'Dwarka', 28.6149318, 77.0227861]
# ['South West Delhi', 'Najafgarh', 28.527295, 77.0823049]
# ['South West Delhi', 'Kapashera', 28.527295, 77.0823049]
# ['South Delhi', 'Saket', 28.5244107, 77.2137253]
# ['South Delhi', 'Hauz Khas', 28.5218262, 77.1783232]
# ['South Delhi', 'Mehrauli', 28.5218262, 77.1783232]
# ['South East Delhi', 'Defence Colony', 28.5717909, 77.2320102]
# ['South East Delhi', 'Kalkaji', 28.5334785, 77.2935232]
# ['South East Delhi', 'Sarita Vihar', 28.5334785, 77.2935232]
# ['Central Delhi', 'Kotwali', 28.6585978, 77.2310844]
# ['Central Delhi', 'Civil Lines', 28.6529982, 77.1890227]
# ['Central Delhi', 'Karol Bagh', 28.6529982, 77.1890227]
# ['Central Delhi', 'Daryaganj', 28.64609, 77.243048]
# ['North East Delhi', 'Seelampur', 28.6706535, 77.264356]
# ['North East Delhi', 'Yamuna Vihar', 28.7311406, 77.2747898]
# ['North East Delhi', 'Karawal Nagar', 28.7311406, 77.2747898]
# ['North East Delhi', 'Nand Nagri', 28.6944581, 77.3161438158589]
# ['Shahdara', 'Shahdara', 28.6773038, 77.2903467]
# ['Shahdara', 'Seemapuri', 28.6691641, 77.312266954216]
# ['Shahdara', 'Vivek Vihar', 28.6691641, 77.312266954216]
# ['East Delhi', 'Gandhi Nagar', 28.65572225, 77.268813153414]
# ['East Delhi', 'Preet Vihar', 28.6133497, 77.2955378]
# ['East Delhi', 'Mayur Vihar', 28.6133497, 77.2955378]

# %% [markdown]
# Getting Latitudes and Longitudes of Delhi to plot

# %%
address = 'Delhi'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# Plotting all the neighbourhoods and making the maps

# %%
map_delhi = folium.Map(location=[latitude, longitude], zoom_start=9.5)
for lat, lng, district, neighbourhood in zip(df['Latitude'], df['Longitude'],df['District'], df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_delhi)  
map_delhi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Returns a list of likes corresponding to the venue id

# %%
import json
def getlikes(names,venue_id, radius = 500):
    CLIENT_ID = 'AQJZAR2CDWN5F5SHA1KTVU1U3G1OLXYJVQ3G14H5MZG2Q5OA' # your Foursquare ID             
    CLIENT_SECRET = 'Y5RWWZ1UNAQZW01HYWP00KPIUKPDFDNVCI42IWMP1Q0SD4A4' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    like_list=[]
    for name,venid in zip(names, venue_id):
        print(name)
        url = 'https://api.foursquare.com/v2/venues/{}/likes?&client_id={}&client_secret={}&v={}'.format(
        venid,
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION)
        like_result = requests.get(url).json()['response']
        like_list.append(like_result['likes']['count'])
    return like_list

# %% [markdown]
# Returns a list of venues corresponding Neighbourhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius = 500):
    #Pass in list of names, latitude, longitude
    CLIENT_ID = 'AQJZAR2CDWN5F5SHA1KTVU1U3G1OLXYJVQ3G14H5MZG2Q5OA' # your Foursquare ID
    CLIENT_SECRET = 'Y5RWWZ1UNAQZW01HYWP00KPIUKPDFDNVCI42IWMP1Q0SD4A4' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    venues_list=[]
    
    for name, lat, long in zip(names, latitudes, longitudes):
        print(name)
        limit = 100
        temp_latitude = lat
        temp_longitude = long
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section=food'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            temp_latitude, 
            temp_longitude, 
            radius, 
            limit)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
#         url = 'https://api.foursquare.com/v2/venues/venue_id={}/likes?&client_id={}&client_secret={}&v={}'.format(
#             results['venue']['id'],
#             CLIENT_ID, 
#             CLIENT_SECRET, 
#             VERSION)
#         like_result = requests.get(url).json()['response']
        venues_list.append([(
            name, 
            lat, 
            long, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name'],
            v['venue']['id']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
            'Neighbourhood Latitude', 
            'Neighbourhood Longitude', 
            'Venue',
            'Venue Latitude', 
            'Venue Longitude', 
            'Venue Category',
            'Venue Id']
    return(nearby_venues)

# %%
Make a data frame of all the colums listed below

# %%
DelhiRestaurants = pd.DataFrame(columns = ['Neighbourhood', 
            'Neighbourhood Latitude', 
            'Neighbourhood Longitude', 
            'Venue',
            'Venue Latitude', 
            'Venue Longitude', 
            'Venue Category',
            'Venue Id',
            'Likes'])
DelhiRestaurants = getNearbyVenues(names=df['Neighbourhood'],
                                latitudes=df['Latitude'],
                                longitudes=df['Longitude']
                                )
DelhiRestaurants['Likes'] = 0;
# Out:
# Chanakyapuri
# Delhi Cantonment
# Vasant Vihar
# Connaught Place
# Model Town
# Narela
# Alipur
# Rohini
# Kanjhawala
# Saraswati Vihar
# Patel Nagar
# Punjabi Bagh
# Rajouri Garden
# Dwarka
# Najafgarh
# Kapashera
# Saket
# Hauz Khas
# Mehrauli
# Defence Colony
# Kalkaji
# Sarita Vihar
# Kotwali
# Civil Lines
# Karol Bagh
# Daryaganj
# Seelampur
# Yamuna Vihar
# Karawal Nagar
# Nand Nagri
# Shahdara
# Seemapuri
# Vivek Vihar
# Gandhi Nagar
# Preet Vihar
# Mayur Vihar

# %% [markdown]
# Writing the data in a file

# %%
with open ("DelhiRestaurants.csv", 'w') as f:
    writer = csv.writer(f, delimiter = ",")
    for data in range(0,DelhiRestaurants.shape[0]):
        writer.writerow(DelhiRestaurants.iloc[data, :])
DelhiRestaurants.head()
df = DelhiRestaurants

# %% [markdown]
# Getting likes of corresponding restaurants and addng it to the data frame

# %%
result = getlikes(df['Venue'],df['Venue Id'])
df['Likes'] = result
df.head()
# Out:
# Samawar - The Coffee Shop
# Sartoria
# The Piano Man Art Cafe
# Yo! China
# McDonald's
# KFC
# Dunkin' Donuts
# Barista Lavazza
# Kylin
# The Asia Kitchen
# Nirula's
# New CCD,Priya complex
# Soi Thai
# Barrels
# Pizza Hut
# krips
# Sartoria
# The Piano Man Art Cafe
# Yo! China
# McDonald's
# KFC
# Dunkin' Donuts
# Barista Lavazza
# Kylin
# The Asia Kitchen
# Nirula's
# New CCD,Priya complex
# Soi Thai
# Barrels
# Pizza Hut
# krips
# Wenger's
# Farzi Cafe
# Chaayos
# Rajdhani Thali
# Johnny Rockets
# United Coffee House
# Nando's
# Khan Chacha | खान चाचा | خان چاچا
# Pind Balluchi
# HOTEL SARAVANA BHAVAN
# Tamasha
# Barbeque Nation
# Berco's
# Nizam's Kathi Kabab | निजा़म काठी कबाब
# Odeon Social
# Immigrants Project - A Cafe in History
# Sagar Ratna
# Warehouse Cafe
# Wenger's Deli
# Fresc Co
# Dunkin' Donuts
# Anand Biryani House
# Chew
# Shake square
# Costa Coffee
# Panchayat Paan Parlour
# Garam Dharam
# Smoke House Deli
# Kwality Restaurant
# Burger King
# Zen Chinese, Connaught Place
# McDonald’s
# Japanese Fuji Restaurant
# Haldiram's
# Veda Restaurant
# KFC
# Domino's Pizza
# Ignis
# McDonald's
# McDonald's
# Side Wok
# Pizza Hut
# Depauls Cold Coffee
# Punjabi by Nature Quickie
# Kake-Da-Hotel
# Comesum
# McDonald's
# Domino's Pizza
# Indian Coffee House
# Minar
# Fa Yian
# Gola Sizzlers
# FIRE
# Biryani Paradise
# MIST
# Lady Baga
# Caffe9
# G
# Fifty9
# SIDEWOK
# The Great Kabab Factory
# China Garden
# Hira Sweets, CP
# The Darzi Bar & Kitchen
# Pioneer's Flavour of China
# Zizo
# Sandoz CP
# Flavours Of China
# Pentamed Canteen
# Hot-Pot
# Dunkin Donuts
# Pizza Hut
# Domino's Pizza
# McDonald's
# Grand Plaza
# Haldiram's
# McDonald's
# KFC UnityOne Mall Rohini
# Nine 2 Eleven
# New York Creamery & Cafe
# Blue Moon Restaurant
# Haldirams
# Dunkin' Donuts
# McDonald's
# Bisque
# Domino's Pizza
# TGI Friday's
# KFC
# Burger King
# Pizza Hut
# Haldiram's @ Sahara Mall
# Coriander Leaf
# McDonald's
# Salsa Salsa
# Not Just Paranthas
# The Chowk
# Ruby's Bar & Grill
# Baujee Ka Dhaba
# TGIF Metropolitan Mall
# Rajdhani Thali - Metropolitian Mall, Gurgoan
# Moet's Curry Pot
# Haldirams
# Dunkin' Donuts
# McDonald's
# Bisque
# Domino's Pizza
# TGI Friday's
# KFC
# Burger King
# Pizza Hut
# Haldiram's @ Sahara Mall
# Coriander Leaf
# McDonald's
# Salsa Salsa
# Not Just Paranthas
# The Chowk
# Ruby's Bar & Grill
# Baujee Ka Dhaba
# TGIF Metropolitan Mall
# Rajdhani Thali - Metropolitian Mall, Gurgoan
# Moet's Curry Pot
# Cafe Coffee Day
# Pirates of The Grill
# sardar ji malai chaap wale
# Street food near Cyber Park
# Gulati Bakers
# Pirates of The Grill
# sardar ji malai chaap wale
# Street food near Cyber Park
# Gulati Bakers
# Dilli 99 Restaurent
# Doodles Cakes
# doodles
# Cheese chaplin
# Dilli 99 Restaurent
# Doodles Cakes
# doodles
# Cheese chaplin
# Dakshin
# Hard Rock Cafe New Delhi
# Mahabelly
# Baywatch, Sheraton Saket
# Rajdhani Thali
# Barbeque Nation Saket
# Pan Asian
# Chili's
# Yo China Cafe
# Dhaba
# Thai High
# Tonino Ristorante
# lavaash by Saby
# THAI HIGH at the Qutab
# Thai High
# Tonino Ristorante
# lavaash by Saby
# THAI HIGH at the Qutab
# Sagar South Indian Restaurant
# Swagath Restaurant & Bar
# Amici Cafe
# Moets Stone
# Brown sugar
# Colonel's Kababz
# Defence Colony Bakery
# Angels In My Kitchen
# subway
# Moets Sizzlers
# Ca Va
# Kent's
# Sagar Ratna
# Akasaka
# Kathputli
# Liquid Kitchen
# Little Dragon Chinese Van
# Yoko Sizzlers
# Barista
# Cafe Coffee Day
# Grill & Fire
# Barista
# Cafe Coffee Day
# Grill & Fire
# Haldiram's
# Parawthe Wale
# Babu Ram Paranthe Wale
# McDonald's
# Pt. Gaya Prasad Shiv Charan Paranthewale | पंडित गया प्रसाद शिव चरण परांठे वाले
# Natraj | नटराज
# McDonald's
# McDonald's
# Ganga Bhojnayala
# Pt. Kanhaiya Lal Durga Prashad Dixit Parawthe Wala
# Wah Ji Wah
# Old Famous Jalebi Waala
# Comesum
# Om corner
# Wah Ji Wah,
# Subway
# Sindhi tikki corner
# Om corner
# Wah Ji Wah,
# Subway
# Sindhi tikki corner
# Changezi Chicken
# Moti Mahal
# Prince Paan
# Zaika
# Domino's Pizza
# New Shahi Food Corner
# Halidrams
# Morning Corner
# Jheel chowk
# Chawla chicken.
# Badnam Tea
# Eat Out Chinese Van
# Badnam Tea
# Eat Out Chinese Van
#       Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0      Chanakyapuri               28.594677                77.188521
# 1  Delhi Cantonment               28.560691                77.160791
# 2  Delhi Cantonment               28.560691                77.160791
# 3  Delhi Cantonment               28.560691                77.160791
# 4  Delhi Cantonment               28.560691                77.160791
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  Samawar - The Coffee Shop       28.597267        77.191812
# 1                   Sartoria       28.558937        77.164182
# 2     The Piano Man Art Cafe       28.557488        77.163979
# 3                  Yo! China       28.557967        77.164270
# 4                 McDonald's       28.557372        77.163521
#
#          Venue Category                  Venue Id  Likes
# 0                 Diner  568bb2ad498e81914839e963      0
# 1    Italian Restaurant  4bc9e9870687ef3b23bddacc      8
# 2                  Café  50a74456e4b0f0765f66162e     19
# 3    Chinese Restaurant  4c8618d047cc224b3929a69f      4
# 4  Fast Food Restaurant  4d4519741928a35d6838c070     21

# %%
df.head()
# Out:
#       Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0      Chanakyapuri               28.594677                77.188521
# 1  Delhi Cantonment               28.560691                77.160791
# 2  Delhi Cantonment               28.560691                77.160791
# 3  Delhi Cantonment               28.560691                77.160791
# 4  Delhi Cantonment               28.560691                77.160791
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0  Samawar - The Coffee Shop       28.597267        77.191812
# 1                   Sartoria       28.558937        77.164182
# 2     The Piano Man Art Cafe       28.557488        77.163979
# 3                  Yo! China       28.557967        77.164270
# 4                 McDonald's       28.557372        77.163521
#
#          Venue Category                  Venue Id  Likes
# 0                 Diner  568bb2ad498e81914839e963      0
# 1    Italian Restaurant  4bc9e9870687ef3b23bddacc      8
# 2                  Café  50a74456e4b0f0765f66162e     19
# 3    Chinese Restaurant  4c8618d047cc224b3929a69f      4
# 4  Fast Food Restaurant  4d4519741928a35d6838c070     21

# %% [markdown]
# Dropping 'Neighbourhood' for clustering of restaurants based on latitudes, longitudes, and likes

# %%
df_main = df[['Neighbourhood','Venue Latitude', 'Venue Longitude', 'Likes']]
df_cluster = df_main.drop(['Neighbourhood'], 1)
# Out:
#       Neighbourhood  Venue Latitude  Venue Longitude  Likes
# 0      Chanakyapuri       28.597267        77.191812      0
# 1  Delhi Cantonment       28.558937        77.164182      8
# 2  Delhi Cantonment       28.557488        77.163979     19
# 3  Delhi Cantonment       28.557967        77.164270      4
# 4  Delhi Cantonment       28.557372        77.163521     21

# %% [markdown]
# Clustering data

# %%
from sklearn.cluster import KMeans
kclusters = 4
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_cluster)
kmeans.labels_[0:10]
# Out:
# array([0, 0, 3, 0, 3, 0, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# Adding Cluster Labels in data frames

# %%
df_main = df_main.drop('Cluster Labels',1)
df_main.insert(0, 'Cluster Labels', kmeans.labels_)
df_main
# Out:
#      Cluster Labels     Neighbourhood  Venue Latitude  Venue Longitude  Likes
# 0                 0      Chanakyapuri       28.597267        77.191812      0
# 1                 0  Delhi Cantonment       28.558937        77.164182      8
# 2                 3  Delhi Cantonment       28.557488        77.163979     19
# 3                 0  Delhi Cantonment       28.557967        77.164270      4
# 4                 3  Delhi Cantonment       28.557372        77.163521     21
# 5                 0  Delhi Cantonment       28.557477        77.164089      4
# 6                 0  Delhi Cantonment       28.557533        77.164163     10
# 7                 0  Delhi Cantonment       28.559194        77.163854      1
# 8                 0  Delhi Cantonment       28.561145        77.157560      0
# 9                 0  Delhi Cantonment       28.558755        77.164037      6
# 10                0  Delhi Cantonment       28.558971        77.163865      0
# 11                0  Delhi Cantonment       28.558829        77.163904      0
# 12                0  Delhi Cantonment       28.557990        77.163854      0
# 13                0  Delhi Cantonment       28.557719        77.164297      4
# 14                0  Delhi Cantonment       28.557583        77.164071      5
# 15                0  Delhi Cantonment       28.557360        77.164062      1
# 16                0      Vasant Vihar       28.558937        77.164182      8
# 17                3      Vasant Vihar       28.557488        77.163979     19
# 18                0      Vasant Vihar       28.557967        77.164270      4
# 19                3      Vasant Vihar       28.557372        77.163521     21
# 20                0      Vasant Vihar       28.557477        77.164089      4
# 21                0      Vasant Vihar       28.557533        77.164163     10
# 22                0      Vasant Vihar       28.559194        77.163854      1
# 23                0      Vasant Vihar       28.561145        77.157560      0
# 24                0      Vasant Vihar       28.558755        77.164037      6
# 25                0      Vasant Vihar       28.558971        77.163865      0
# 26                0      Vasant Vihar       28.558829        77.163904      0
# 27                0      Vasant Vihar       28.557990        77.163854      0
# 28                0      Vasant Vihar       28.557719        77.164297      4
# 29                0      Vasant Vihar       28.557583        77.164071      5
# ..              ...               ...             ...              ...    ...
# 216               0           Kotwali       28.656357        77.230587     15
# 217               0           Kotwali       28.661289        77.227164      2
# 218               0           Kotwali       28.656162        77.234208     12
# 219               0           Kotwali       28.656193        77.230442      0
# 220               0           Kotwali       28.656109        77.230465      1
# 221               0           Kotwali       28.656299        77.233081      0
# 222               0           Kotwali       28.656012        77.233604      1
# 223               0           Kotwali       28.660668        77.227810      5
# 224               0       Civil Lines       28.654090        77.189957      4
# 225               0       Civil Lines       28.653929        77.189889      1
# 226               0       Civil Lines       28.652046        77.191271      3
# 227               0       Civil Lines       28.655119        77.190971      5
# 228               0        Karol Bagh       28.654090        77.189957      4
# 229               0        Karol Bagh       28.653929        77.189889      1
# 230               0        Karol Bagh       28.652046        77.191271      3
# 231               0        Karol Bagh       28.655119        77.190971      5
# 232               0         Daryaganj       28.643751        77.240486     10
# 233               3         Daryaganj       28.646523        77.240145     19
# 234               0         Daryaganj       28.646546        77.240170      3
# 235               0         Daryaganj       28.643592        77.240437      1
# 236               0         Daryaganj       28.643000        77.241000      0
# 237               0          Shahdara       28.676237        77.290450      0
# 238               0          Shahdara       28.675918        77.290126      1
# 239               0          Shahdara       28.679894        77.287361      1
# 240               0      Gandhi Nagar       28.656600        77.272665      3
# 241               0      Gandhi Nagar       28.656626        77.272710      0
# 242               0       Preet Vihar       28.610785        77.296180      2
# 243               0       Preet Vihar       28.613002        77.291002      1
# 244               0       Mayur Vihar       28.610785        77.296180      2
# 245               0       Mayur Vihar       28.613002        77.291002      1
#
# [246 rows x 5 columns]

# %% [markdown]
# PLotting the restaurants along with their likes and clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)


# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_main['Venue Latitude'], df_main['Venue Longitude'], df_main['Neighbourhood'], df_main['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
